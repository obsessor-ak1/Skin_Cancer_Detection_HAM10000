# %% [markdown]
# # Data Augmentation
# In this notebook, we will be performing data augmentation to generate a new dataset, with no class imbalance.

# %%
from exp_tools.aug_data import generate_augmented_data_ham10000

# %% [markdown]
# ## Dataset Generation
# Let's generate the dataset, with 8000 images per class, with data augmentation.

# %%
NUM_IMAGES_PER_CLASS = 8000
ORIGINAL_SOURCE_PATH = "../data/HMNIST"
DEST_DATASET_PATH = "../data/HMNIST_AUG"
NUM_WORKERS = 8
TRAIN_SIZE = 0.85

# %%
# %%time
generate_augmented_data_ham10000(
    source_dir=ORIGINAL_SOURCE_PATH,
    dest_dir=DEST_DATASET_PATH,
    ratio=TRAIN_SIZE,
    num_samples_per_class=NUM_IMAGES_PER_CLASS,
    num_workers=NUM_WORKERS
)
# Out:
# Loaded image directories and metadata....✅
# [bkl] train: 8000, test: 165 augmentation started...
# [nv] train: 8000, test: 1006 augmentation started...
# [df] train: 8000, test: 18 augmentation started...
# [mel] train: 8000, test: 167 augmentation started...
# [vasc] train: 8000, test: 22 augmentation started...
# [bcc] train: 8000, test: 78 augmentation started...
# [akiec] train: 8000, test: 50 augmentation started...
# ✅ Augmentation complete.
# CPU times: total: 1min 57s
# Wall time: 20min 29s
